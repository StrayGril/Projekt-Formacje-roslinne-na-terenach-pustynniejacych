# %%
import sys
import os

# Dodanie katalogu głównego repo do ścieżki
sys.path.append(os.path.abspath(".."))

import numpy as np
import matplotlib.pyplot as plt
from pipeline.parametres_search import scan_turing_am, plot_lambda_map, plot_turing_regions

# zakres m i a
m_values = np.arange(0.1, 1.51, 0.1)
a_values = np.linspace(0.0, 6.0, 250)

# %%
# Szukamy minimum d1 >> d2
d1_vals = np.arange(0.1, 1.1, 0.1)
d2 = 0.06

fig, axes = plt.subplots(len(d1_vals), 2, figsize=(14, 4 * len(d1_vals)))
for i, d1 in enumerate(d1_vals):
    results = scan_turing_am(d1, d2, m_values=m_values, a_values=a_values, k_min = 0, k_max=20, n_k=1000)
    
    plot_lambda_map(results, ax=axes[i, 0])
    plot_turing_regions(results, ax=axes[i, 1])

    axes[i, 0].set_title(fr"maxRe($\lambda$), d1={d1:.1f}, d2={d2}")
    axes[i, 1].set_title(f"Obszary, d1={d1:.1f}, d2={d2}")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 9
#       6 for i, d1 in enumerate(d1_vals):
#       7     results = scan_turing_am(d1, d2, m_values=m_values, a_values=a_values, k_min = 0, k_max=20, n_k=1000)
# ----> 9     plot_lambda_map(results, ax=axes[i, 0])
#      10     plot_turing_regions(results, ax=axes[i, 1])
#      12     axes[i, 0].set_title(fr"maxRe($\lambda$), d1={d1:.1f}, d2={d2}")
#
# File ~\PycharmProjects\Projekt-Formacje-roslinne-na-terenach-pustynniejacych\pipeline\parametres_search.py:122, in plot_lambda_map(results, ax)
#     118 def plot_lambda_map(results, ax=None):
#     119     """
#     120     Rysuje mapę max Re(lambda) w płaszczyźnie (a, m).
#     121     """
# --> 122     A, M, S, T, L, V, K1, K2, KD = unpack_scan_results(results)
#     124     mask = np.isfinite(L)
#     126     if ax is None:
#
# File ~\PycharmProjects\Projekt-Formacje-roslinne-na-terenach-pustynniejacych\pipeline\parametres_search.py:114, in unpack_scan_results(results)
#     112 K1 = np.array([r["k_left"] for r in results])
#     113 K2 = np.array([r["k_right"] for r in results])
# --> 114 KD = np.array([r["k_dom"] for r in results])
#     116 return A, M, S, T, L, V, K1, K2, KD
#
# KeyError: 'k_dom'

# %%
# Szukamy masimum d1 >> d2
d1_vals = np.arange(0, 100, 5)
d1_vals[0] = 1
d2 = 0.02

fig, axes = plt.subplots(len(d1_vals), 2, figsize=(14, 4 * len(d1_vals)))
for i, d1 in enumerate(d1_vals):
    results = scan_turing_am(d1, d2, m_values=m_values, a_values=a_values, k_min = 0, k_max=20, n_k=1000)
    
    plot_lambda_map(results, ax=axes[i, 0])
    plot_turing_regions(results, ax=axes[i, 1])

    axes[i, 0].set_title(fr"maxRe($\lambda$), d1={d1:.1f}, d2={d2}")
    axes[i, 1].set_title(f"Obszary, d1={d1:.1f}, d2={d2}")
plt.tight_layout()
plt.show()

# %%
# Szukamy dobrego d2 << d1
d1 = 20
d2_vals = np.arange(0.01, 1.01, 0.1)

fig, axes = plt.subplots(len(d2_vals), 2, figsize=(14, 4 * len(d2_vals)))
for i, d2 in enumerate(d2_vals):
    results = scan_turing_am(d1, d2, m_values=m_values, a_values=a_values, k_min = 0, k_max=20, n_k=1000)
    
    plot_lambda_map(results, ax=axes[i, 0])
    plot_turing_regions(results, ax=axes[i, 1])

    axes[i, 0].set_title(fr"maxRe($\lambda$), d1={d1:.1f}, d2={d2}")
    axes[i, 1].set_title(f"Obszary, d1={d1:.1f}, d2={d2}")
plt.tight_layout()
plt.show()

# %%
# Szukamy masimum d1 >> d2
d1_vals = np.arange(0, 100, 5)
d1_vals[0] = 1
d2 = 0.02

fig, axes = plt.subplots(len(d1_vals), 2, figsize=(14, 4 * len(d1_vals)))
for i, d1 in enumerate(d1_vals):
    results = scan_turing_am(d1, d2, m_values=m_values, a_values=a_values, k_min = 0, k_max=20, n_k=1000)
    
    plot_lambda_map(results, ax=axes[i, 0])
    plot_turing_regions(results, ax=axes[i, 1])

    axes[i, 0].set_title(fr"maxRe($\lambda$), d1={d1:.1f}, d2={d2}")
    axes[i, 1].set_title(f"Obszary, d1={d1:.1f}, d2={d2}")
plt.tight_layout()
plt.show()

# %%
# Szukamy dobrego d2 << d1
d1 = 100
d2_vals = [0.02]

fig, axes = plt.subplots(len(d2_vals), 2, figsize=(14, 4 * len(d2_vals)), squeeze=False)
for i, d2 in enumerate(d2_vals):
    results = scan_turing_am(d1, d2, m_values=m_values, a_values=a_values, k_min = 0, k_max=20, n_k=1000)
    
    plot_lambda_map(results, ax=axes[i, 0])
    plot_turing_regions(results, ax=axes[i, 1])

    axes[i, 0].set_title(fr"maxRe($\lambda$), d1={d1:.1f}, d2={d2}")
    axes[i, 1].set_title(f"Obszary, d1={d1:.1f}, d2={d2}")
plt.tight_layout()
plt.show()

# %%
# Szukamy dobrego d2 << d1
d1 = 100
d2_vals = [d1 / 10**1, d1 / 10**2, d1 / 10**3, d1 / 10**4, d1 / 10**5,]

fig, axes = plt.subplots(len(d2_vals), 2, figsize=(14, 4 * len(d2_vals)), squeeze=False)
for i, d2 in enumerate(d2_vals):
    results = scan_turing_am(d1, d2, m_values=m_values, a_values=a_values, k_min = 0, k_max=20, n_k=1000)
    
    plot_lambda_map(results, ax=axes[i, 0])
    plot_turing_regions(results, ax=axes[i, 1])

    axes[i, 0].set_title(fr"maxRe($\lambda$), d1={d1:.1f}, d2={d2}")
    axes[i, 1].set_title(f"Obszary, d1={d1:.1f}, d2={d2}")
plt.tight_layout()
plt.show()

## Wniosek: mega ważny jest stosunek d1 / d2 - czym większy, tym lepszy
